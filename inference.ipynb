# %%
import argparse
import os
from solver import Solver
from torch.backends import cudnn
from data_loader import get_loader

# %%
# !python main.py --use_labels=True --use_reconst_loss=True
# Out:
# Namespace(image_size=32, g_conv_dim=64, d_conv_dim=64, use_reconst_loss=True, use_labels=True, num_classes=10, train_iters=40000, batch_size=64, num_workers=2, lr=0.0002, beta1=0.5, beta2=0.999, mode='train', model_path='./models', sample_path='./samples', mnist_path='./mnist', svhn_path='./svhn', log_step=10, sample_step=500)
# Step [10/40000], d_real_loss: 3.6549, d_mnist_loss: 1.0948, d_svhn_loss: 2.5601, d_fake_loss: 0.5387, g_loss: 5.3042
# Step [20/40000], d_real_loss: 3.1410, d_mnist_loss: 0.7501, d_svhn_loss: 2.3910, d_fake_loss: 0.4539, g_loss: 5.8285
# Step [30/40000], d_real_loss: 2.8657, d_mnist_loss: 0.5154, d_svhn_loss: 2.3503, d_fake_loss: 0.6095, g_loss: 5.9740
# Step [40/40000], d_real_loss: 3.1662, d_mnist_loss: 0.4860, d_svhn_loss: 2.6802, d_fake_loss: 0.7858, g_loss: 6.4697
# Step [50/40000], d_real_loss: 3.0957, d_mnist_loss: 0.6726, d_svhn_loss: 2.4230, d_fake_loss: 0.8642, g_loss: 7.2882
# ...

# %%
parser = argparse.ArgumentParser()
    
# model hyper-parameters
parser.add_argument('--image_size', type=int, default=32)
parser.add_argument('--g_conv_dim', type=int, default=64)
parser.add_argument('--d_conv_dim', type=int, default=64)
parser.add_argument('--use_reconst_loss', type=bool, default=True)
parser.add_argument('--use_labels', type=bool, default=False)
parser.add_argument('--num_classes', type=int, default=10)

# training hyper-parameters
parser.add_argument('--train_iters', type=int, default=40000)
parser.add_argument('--batch_size', type=int, default=64)
parser.add_argument('--num_workers', type=int, default=2)
parser.add_argument('--lr', type=float, default=0.0002)
parser.add_argument('--beta1', type=float, default=0.5)
parser.add_argument('--beta2', type=float, default=0.999)

# misc
parser.add_argument('--mode', type=str, default='train')
parser.add_argument('--model_path', type=str, default='./models')
parser.add_argument('--sample_path', type=str, default='./samples')
parser.add_argument('--mnist_path', type=str, default='./mnist')
parser.add_argument('--svhn_path', type=str, default='./svhn')
parser.add_argument('--log_step', type=int , default=10)
parser.add_argument('--sample_step', type=int , default=500)

config, unknown = parser.parse_known_args()
print(config)
# Out:
# Namespace(image_size=32, g_conv_dim=64, d_conv_dim=64, use_reconst_loss=True, use_labels=False, num_classes=10, train_iters=40000, batch_size=64, num_workers=2, lr=0.0002, beta1=0.5, beta2=0.999, mode='train', model_path='./models', sample_path='./samples', mnist_path='./mnist', svhn_path='./svhn', log_step=10, sample_step=500)

# %%
svhn_loader, mnist_loader = get_loader(config, False)
    
solver = Solver(config, svhn_loader, mnist_loader)
cudnn.benchmark = True
# Out:
# /home/voila_off/virtualenvs/train_gan/lib/python3.9/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 2 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
solver.mnist_to_svhn(30000)

# %%
solver.mnist_to_mnist()

# %%
solver.svhn_to_svhn()
